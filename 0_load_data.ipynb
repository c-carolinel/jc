# %%
load allPlanesVariables27-Feb-2021.mat
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~/Documents/coding files/senior research/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:4031, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    4030 try:                                              # User namespace
# -> 4031     codeobj = eval(target, self.user_ns)
#    4032 except Exception as e:
#
# SyntaxError: invalid decimal literal (<string>, line 1)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('load', 'allPlanesVariables27-Feb-2021.mat')
#
# File ~/Documents/coding files/senior research/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/coding files/senior research/.venv/lib/python3.13/site-packages/IPython/core/magics/code.py:361, in CodeMagics.load(self, arg_s)
#     359 opts,args = self.parse_options(arg_s,'yns:r:')
#     360 search_ns = 'n' in opts
# --> 361 contents = self.shell.find_user_code(args, search_ns=search_ns)
#     363 if 's' in opts:
#     364     try:
#
# File ~/Documents/coding files/senior research/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:4033, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    4031     codeobj = eval(target, self.user_ns)
#    4032 except Exception as e:
# -> 4033     raise ValueError(("'%s' was not found in history, as a file, url, "
#    4034                         "nor in the user namespace.") % target) from e
#    4036 if isinstance(codeobj, str):
#    4037     return codeobj
#
# ValueError: 'allPlanesVariables27-Feb-2021.mat' was not found in history, as a file, url, nor in the user namespace.

# %%
% 3D-plot of each plane indicating the location of the neurons
for i = 2:6
    figure(i)
    plot3(allxc{i,1}, allyc{i,1}, allzc{i,1}, 'o')
end

# %%
% Graph the activity of the first neuron in the second plane
planeNumber = 2;
ActivityForAllNeurons = zDFF{planeNumber};
neuronID = 1;
figure(1)
plot(ActivityForAllNeurons(neuronID,:))

# %%
% Convert zDFF for plane 2 into a CSV 
csvwrite('data.csv', ActivityForAllNeurons);
