# %%
load allPlanesVariables27-Feb-2021.mat

# %%
% Extract zDFF data for planes 2-6
combinedData = []; 

% Loop through planes 2 to 6
for plane = 2:6
    currentPlaneData = zDFF{plane};
    % Vertically concatenate
    combinedData = [combinedData; currentPlaneData];
end

csvwrite('data_allplanes.csv', combinedData);
